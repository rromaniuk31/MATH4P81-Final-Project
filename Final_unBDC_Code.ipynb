# %% [markdown]
# ## Import the Things

# %%
import pandas as pd
import numpy as np
from datetime import date

url1 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv"
url2 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-23-2020.csv"
url3 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-24-2020.csv"
url4 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-25-2020.csv"
url5 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-26-2020.csv"
url6 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-27-2020.csv"
url7 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-28-2020.csv"
url8 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-29-2020.csv"
url9 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-30-2020.csv"
url10 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-31-2020.csv"
url11 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-01-2020.csv"
url12 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-02-2020.csv"
url13 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-03-2020.csv"
url14 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-04-2020.csv"
url15 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-05-2020.csv"
url16 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-06-2020.csv"
url17 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-07-2020.csv"
url18 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-08-2020.csv"
url19 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-09-2020.csv"
url20 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-10-2020.csv"
url21 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-11-2020.csv"
url22 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-12-2020.csv"
url23 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-13-2020.csv"
url24 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-14-2020.csv"
url25 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-15-2020.csv"
url26 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-16-2020.csv"
url27 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-17-2020.csv"
url28 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-18-2020.csv"
url29 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-19-2020.csv"
url30 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-20-2020.csv"
url31 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-21-2020.csv"
url32 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-22-2020.csv"
url33 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-23-2020.csv"
url34 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-24-2020.csv"
url35 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-25-2020.csv"
url36 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-26-2020.csv"
url37 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-27-2020.csv"
url38 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-28-2020.csv"
url39 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-29-2020.csv"
url40 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-01-2020.csv"
url41 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-02-2020.csv"
url42 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-03-2020.csv"
url43 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-04-2020.csv"
url44 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-05-2020.csv"
url45 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-06-2020.csv"
url46 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-07-2020.csv"
url47 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-08-2020.csv"
url48 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-09-2020.csv"
url49 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-10-2020.csv"
url50 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-11-2020.csv"
url51 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-12-2020.csv"
url52 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-13-2020.csv"
url53 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-14-2020.csv"
url54 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-15-2020.csv"
url55 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-16-2020.csv"
url56 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv"
url57 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-18-2020.csv"
url58 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-19-2020.csv"
url59 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-20-2020.csv"
url60 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-21-2020.csv"
url61 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv"
url62 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv"
url63 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-24-2020.csv"
url64 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-25-2020.csv"
url65 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-26-2020.csv"
url66 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-27-2020.csv"
url67 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-28-2020.csv"
url68 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-29-2020.csv"
url69 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-30-2020.csv"
url70 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-31-2020.csv"
url71 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv"
url72 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv"
url73 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-03-2020.csv"
url74 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv"
url75 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-05-2020.csv"
url76 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-06-2020.csv"
url77 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-07-2020.csv"
url78 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-08-2020.csv"
url79 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-09-2020.csv"
url80 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-10-2020.csv"
url81 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-11-2020.csv"
url82 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-12-2020.csv"
url83 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-13-2020.csv"
url84 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-14-2020.csv"
url85 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-15-2020.csv"
url86 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-16-2020.csv"
url87 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-17-2020.csv"
url88 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-18-2020.csv"
url89 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-19-2020.csv"
url90 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-20-2020.csv"
url91 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-21-2020.csv"
url92 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-22-2020.csv"
url93 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-23-2020.csv"
url94 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-24-2020.csv"
url95 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-25-2020.csv"
url96 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-26-2020.csv"
url97 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-27-2020.csv"
url98 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-28-2020.csv"
url99 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-29-2020.csv"
url100 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-30-2020.csv"
url101 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-01-2020.csv"
url102 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-02-2020.csv"
url103 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-03-2020.csv"
url104 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-04-2020.csv"
url105 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-05-2020.csv"
url106 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-06-2020.csv"
url107 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-07-2020.csv"
url108 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-08-2020.csv"
url109 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-09-2020.csv"
url110 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-10-2020.csv"
url111 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-11-2020.csv"
url112 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-12-2020.csv"
url113 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-13-2020.csv"
url114 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-14-2020.csv"
url115 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-15-2020.csv"
url116 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-16-2020.csv"
url117 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-17-2020.csv"
url118 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-18-2020.csv"
url119 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-19-2020.csv"
url120 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-20-2020.csv"
url121 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-21-2020.csv"
url122 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-22-2020.csv"
url123 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-23-2020.csv"
url124 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-24-2020.csv"
url125 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-25-2020.csv"
url126 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-26-2020.csv"
url127 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-27-2020.csv"
url128 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-28-2020.csv"
url129 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-29-2020.csv"
url130 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-30-2020.csv"
#url131 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-31-2020.csv"

# %%
US_PopDen = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2015 USA Population Density.csv")
Can_AgeHouse = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2016 Canadian Avg Age and Household Size.csv")
Can_PopDen = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2016 Canadian Population Density.csv")
Can_Obe = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2017-2012 Canadian Obesity Rate.csv")
Can_GDP = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 Canadian GDP.csv")
US_Age = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA Average Age.csv")
US_House = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA Average Household Size.csv")
US_GDP = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA GDP.csv")
US_Obe = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA Obesity Rate.csv")
USNoNYC_PopDen = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2015 USA (No NYC) Population Density.csv")
USNoNYC_Age = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA (No NYC) Average Age.csv")
USNoNYC_House = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA (No NYC) Average Household Size.csv")
USNoNYC_GDP = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\2018 USA (No NYC) GDP.csv")
Smoking_Drinking = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\Canada & US Smoking and Drinking.csv")

# %% [markdown]
# ## Read CSV's

# %%
df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)
df4 = pd.read_csv(url4)
df5 = pd.read_csv(url5)
df6 = pd.read_csv(url6)
df7 = pd.read_csv(url7)
df8 = pd.read_csv(url8)
df9 = pd.read_csv(url9)
df10 = pd.read_csv(url10)
df11 = pd.read_csv(url11)
df12 = pd.read_csv(url12)
df13 = pd.read_csv(url13)
df14 = pd.read_csv(url14)
df15 = pd.read_csv(url15)
df16 = pd.read_csv(url16)
df17 = pd.read_csv(url17)
df18 = pd.read_csv(url18)
df19 = pd.read_csv(url19)
df20 = pd.read_csv(url20)
df21 = pd.read_csv(url21)
df22 = pd.read_csv(url22)
df23 = pd.read_csv(url23)
df24 = pd.read_csv(url24)
df25 = pd.read_csv(url25)
df26 = pd.read_csv(url26)
df27 = pd.read_csv(url27)
df28 = pd.read_csv(url28)
df29 = pd.read_csv(url29)
df30 = pd.read_csv(url30)
df31 = pd.read_csv(url31)
df32 = pd.read_csv(url32)
df33 = pd.read_csv(url33)
df34 = pd.read_csv(url34)
df35 = pd.read_csv(url35)
df36 = pd.read_csv(url36)
df37 = pd.read_csv(url37)
df38 = pd.read_csv(url38)
df39 = pd.read_csv(url39)
df40 = pd.read_csv(url40)
df41 = pd.read_csv(url41)
df42 = pd.read_csv(url42)
df43 = pd.read_csv(url43)
df44 = pd.read_csv(url44)
df45 = pd.read_csv(url45)
df46 = pd.read_csv(url46)
df47 = pd.read_csv(url47)
df48 = pd.read_csv(url48)
df49 = pd.read_csv(url49)
df50 = pd.read_csv(url50)
df51 = pd.read_csv(url51)
df52 = pd.read_csv(url52)
df53 = pd.read_csv(url53)
df54 = pd.read_csv(url54)
df55 = pd.read_csv(url55)
df56 = pd.read_csv(url56)
df57 = pd.read_csv(url57)
df58 = pd.read_csv(url58)
df59 = pd.read_csv(url59)
df60 = pd.read_csv(url60)
df61 = pd.read_csv(url61)
df62 = pd.read_csv(url62)
df63 = pd.read_csv(url63)
df64 = pd.read_csv(url64)
df65 = pd.read_csv(url65)
df66 = pd.read_csv(url66)
df67 = pd.read_csv(url67)
df68 = pd.read_csv(url68)
df69 = pd.read_csv(url69)
df70 = pd.read_csv(url70)
df71 = pd.read_csv(url71)
df72 = pd.read_csv(url72)
df73 = pd.read_csv(url73)
df74 = pd.read_csv(url74)
df75 = pd.read_csv(url75)
df76 = pd.read_csv(url76)
df77 = pd.read_csv(url77)
df78 = pd.read_csv(url78)
df79 = pd.read_csv(url79)
df80 = pd.read_csv(url80)
df81 = pd.read_csv(url81)
df82 = pd.read_csv(url82)
df83 = pd.read_csv(url83)
df84 = pd.read_csv(url84)
df85 = pd.read_csv(url85)
df86 = pd.read_csv(url86)
df87 = pd.read_csv(url87)
df88 = pd.read_csv(url88)
df89 = pd.read_csv(url89)
df90 = pd.read_csv(url90)
df91 = pd.read_csv(url91)
df92 = pd.read_csv(url92)
df93 = pd.read_csv(url93)
df94 = pd.read_csv(url94)
df95 = pd.read_csv(url95)
df96 = pd.read_csv(url96)
df97 = pd.read_csv(url97)
df98 = pd.read_csv(url98)
df99 = pd.read_csv(url99)
df100 = pd.read_csv(url100)
df101 = pd.read_csv(url101)
df102 = pd.read_csv(url102)
df103 = pd.read_csv(url103)
df104 = pd.read_csv(url104)
df105 = pd.read_csv(url105)
df106 = pd.read_csv(url106)
df107 = pd.read_csv(url107)
df108 = pd.read_csv(url108)
df109 = pd.read_csv(url109)
df110 = pd.read_csv(url110)
df111 = pd.read_csv(url111)
df112 = pd.read_csv(url112)
df113 = pd.read_csv(url113)
df114 = pd.read_csv(url114)
df115 = pd.read_csv(url115)
df116 = pd.read_csv(url116)
df117 = pd.read_csv(url117)
df118 = pd.read_csv(url118)
df119 = pd.read_csv(url119)
df120 = pd.read_csv(url120)
df121 = pd.read_csv(url121)
df122 = pd.read_csv(url122)
df123 = pd.read_csv(url123)
df124 = pd.read_csv(url124)
df125 = pd.read_csv(url125)
df126 = pd.read_csv(url126)
df127 = pd.read_csv(url127)
df128 = pd.read_csv(url128)
df129 = pd.read_csv(url129)
df130 = pd.read_csv(url130)
#df131 = pd.read_csv(url131)

# %% [markdown]
# ## Combine Each Days Data

# %%
all_dfs = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,df71,df72,df73,df74,df75,df76,df77,df78,df79,df80,df81,df82,df83,df84,df85,df86,df87,df88,df89,df90,df91,df92,df93,df94,df95,df96,df97,df98,df99,df100,df101,df102,df103,df104,df105,df106,df107,df108,df109,df110,df111,df112,df113,df114,df115,df116,df117,df118,df119,df120,df121,df122,df123,df124,df125,df126,df127,df128,df129,df130]#,df131]
final_df = pd.concat(all_dfs).reset_index(drop=True)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %% [markdown]
# ## Some Data Clean Up

# %%
final_df['Country/Region'].fillna(final_df['Country_Region'], inplace=True)
del final_df['Country_Region']

final_df['Latitude'].fillna(final_df['Lat'], inplace=True)
del final_df['Lat']

final_df['Longitude'].fillna(final_df['Long_'], inplace=True)
del final_df['Long_']

final_df['Province/State'].fillna(final_df['Province_State'], inplace=True)
del final_df['Province_State']

final_df['Last Update'].fillna(final_df['Last_Update'], inplace=True)
del final_df['Last_Update']

# %% [markdown]
# ## Save Full Dataset as CSV

# %%
final_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\TotalCovid.csv", index = False, sep = ',', encoding = 'utf-8')

# %% [markdown]
# ## Create A Column To Check If Today

# %%
Todayfinal_df = final_df
today = date.today()
Todayfinal_df['timestamp'] = pd.to_datetime(Todayfinal_df['Last Update'])
Todayfinal_df['New Date'] = Todayfinal_df['timestamp'].dt.date
Todayfinal_df['Today?'] = np.where(pd.to_datetime(Todayfinal_df['New Date']) == today, 'Yes', 'No')
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and 'the values will not compare equal to the
# 'datetime.date'. To retain the current behavior, convert the
# 'datetime.date' to a datetime with 'pd.Timestamp'.
#   """

# %% [markdown]
# ## Drop Rows That Are Not Today

# %%
Todayfinal_df = Todayfinal_df.loc[~(Todayfinal_df['Today?'] == "No"),:]

# %% [markdown]
# ## Save Full Today Dataset As CSV

# %%
Todayfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\TodayCovid.csv", index = False, sep = ',', encoding = 'utf-8')

# %% [markdown]
# ## Create Column To Check If North America

# %%
def NorthAmerica(row):
    if row['Country/Region'] == "Canada":
        val = "Yes"
    elif row['Country/Region'] == "US":
        val = "Yes"
    else:
        val = "No"
    return val

NAfinal_df = Todayfinal_df
NAfinal_df['North America?'] = final_df.apply(NorthAmerica, axis=1)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## Drop Rows From Outside North America

# %%
NAfinal_df = NAfinal_df.loc[~(NAfinal_df['North America?'] == "No"),:]
NAfinal_df['ProvinceOrState'] = NAfinal_df['Province/State']
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Create New Canada, USA and Non-NYC

# %%
CAfinal_df = NAfinal_df
USfinal_df = NAfinal_df
NoNYCfinal_df = NAfinal_df
NoDCfinal_df = NAfinal_df #New

# %% [markdown]
# ## Get Rid Of NYC And DC

# %%
NoNYCfinal_df = NoNYCfinal_df.loc[~(NoNYCfinal_df['Admin2'] == "New York City"),:]
NoDCfinal_df = NoDCfinal_df.loc[~(NoDCfinal_df['ProvinceOrState'] == "District of Columbia")] #New
NoNYCDCfinal_df = NoNYCfinal_df.loc[~(NoNYCfinal_df['ProvinceOrState'] == "District of Columbia")] #New

# %% [markdown]
# ## Drop Un-Needed Columns

# %%
NAfinal_df = NAfinal_df.drop(columns=['Admin2', 'FIPS', 'Last Update', 'Latitude', 'Longitude', 'Province/State', 'timestamp', 'New Date', 'Today?', 'North America?', 'Combined_Key'])
CAfinal_df = CAfinal_df.drop(columns=['Admin2', 'FIPS', 'Last Update', 'Latitude', 'Longitude', 'Province/State', 'timestamp', 'New Date', 'Today?', 'North America?', 'Combined_Key'])
USfinal_df = USfinal_df.drop(columns=['Admin2', 'FIPS', 'Last Update', 'Latitude', 'Longitude', 'Province/State', 'timestamp', 'New Date', 'Today?', 'North America?', 'Combined_Key'])
NoNYCfinal_df = NoNYCfinal_df.drop(columns=['Admin2', 'FIPS', 'Last Update', 'Latitude', 'Longitude', 'Province/State', 'timestamp', 'New Date', 'Today?', 'North America?', 'Combined_Key'])
NoDCfinal_df = NoDCfinal_df.drop(columns=['Admin2', 'FIPS', 'Last Update', 'Latitude', 'Longitude', 'Province/State', 'timestamp', 'New Date', 'Today?', 'North America?', 'Combined_Key'])
NoNYCDCfinal_df = NoNYCDCfinal_df.drop(columns=['Admin2', 'FIPS', 'Last Update', 'Latitude', 'Longitude', 'Province/State', 'timestamp', 'New Date', 'Today?', 'North America?', 'Combined_Key'])

# %% [markdown]
# ## Sum Covid Data

# %%
NAfinal_df = NAfinal_df.groupby(['ProvinceOrState']).sum()
NAfinal_df['ProvinceOrState'] = NAfinal_df.index

CAfinal_df = CAfinal_df.groupby(['ProvinceOrState']).sum()
CAfinal_df['ProvinceOrState'] = CAfinal_df.index

USfinal_df = USfinal_df.groupby(['ProvinceOrState']).sum()
USfinal_df['ProvinceOrState'] = USfinal_df.index

NoNYCfinal_df = NoNYCfinal_df.groupby(['ProvinceOrState']).sum()
NoNYCfinal_df['ProvinceOrState'] = NoNYCfinal_df.index

NoDCfinal_df = NoDCfinal_df.groupby(['ProvinceOrState']).sum()
NoDCfinal_df['ProvinceOrState'] = NoDCfinal_df.index

NoNYCDCfinal_df = NoNYCDCfinal_df.groupby(['ProvinceOrState']).sum()
NoNYCDCfinal_df['ProvinceOrState'] = NoNYCDCfinal_df.index

# %% [markdown]
# ## Give States, Provinces & Territories Their ID

# %%
NAfinal_df['LocationID'] = ''
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Alabama",'1',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Alaska",'2',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Arizona",'3',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Arkansas",'4',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "California",'5',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Colorado",'6',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Connecticut",'7',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Delaware",'8',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Florida",'9',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Georgia",'10',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Hawaii",'11',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Idaho",'12',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Illinois",'13',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Indiana",'14',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Iowa",'15',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Kansas",'16',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Kentucky",'17',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Louisiana",'18',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Maine",'19',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Maryland",'20',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Massachusetts",'21',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Michigan",'22',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Minnesota",'23',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Mississippi",'24',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Missouri",'25',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Montana",'26',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Nebraska",'27',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Nevada",'28',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "New Hampshire",'29',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "New Jersey",'30',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "New Mexico",'31',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "New York",'32',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "North Carolina",'33',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "North Dakota",'34',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Ohio",'35',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Oklahoma",'36',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Oregon",'37',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Pennsylvania",'38',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Rhode Island",'39',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "South Carolina",'40',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "South Dakota",'41',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Tennessee",'42',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Texas",'43',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Utah",'44',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Vermont",'45',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Virginia",'46',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Washington",'47',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "West Virginia",'48',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Wisconsin",'49',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Wyoming",'50',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "District of Columbia",'51',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Ontario",'52',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Quebec",'53',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Nova Scotia",'54',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "New Brunswick",'55',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Manitoba",'56',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "British Columbia",'57',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Prince Edward Island",'58',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Saskatchewan",'59',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Alberta",'60',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Newfoundland and Labrador",'61',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Northwest Territories",'62',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Yukon",'63',NAfinal_df.LocationID)
NAfinal_df['LocationID'] = np.where(NAfinal_df.ProvinceOrState == "Nunavut",'64',NAfinal_df.LocationID)

# %%
CAfinal_df['LocationID'] = ''
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Alabama",'1',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Alaska",'2',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Arizona",'3',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Arkansas",'4',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "California",'5',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Colorado",'6',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Connecticut",'7',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Delaware",'8',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Florida",'9',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Georgia",'10',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Hawaii",'11',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Idaho",'12',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Illinois",'13',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Indiana",'14',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Iowa",'15',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Kansas",'16',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Kentucky",'17',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Louisiana",'18',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Maine",'19',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Maryland",'20',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Massachusetts",'21',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Michigan",'22',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Minnesota",'23',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Mississippi",'24',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Missouri",'25',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Montana",'26',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Nebraska",'27',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Nevada",'28',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "New Hampshire",'29',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "New Jersey",'30',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "New Mexico",'31',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "New York",'32',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "North Carolina",'33',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "North Dakota",'34',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Ohio",'35',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Oklahoma",'36',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Oregon",'37',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Pennsylvania",'38',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Rhode Island",'39',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "South Carolina",'40',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "South Dakota",'41',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Tennessee",'42',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Texas",'43',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Utah",'44',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Vermont",'45',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Virginia",'46',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Washington",'47',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "West Virginia",'48',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Wisconsin",'49',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Wyoming",'50',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "District of Columbia",'51',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Ontario",'52',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Quebec",'53',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Nova Scotia",'54',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "New Brunswick",'55',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Manitoba",'56',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "British Columbia",'57',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Prince Edward Island",'58',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Saskatchewan",'59',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Alberta",'60',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Newfoundland and Labrador",'61',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Northwest Territories",'62',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Yukon",'63',CAfinal_df.LocationID)
CAfinal_df['LocationID'] = np.where(CAfinal_df.ProvinceOrState == "Nunavut",'64',CAfinal_df.LocationID)

# %%
USfinal_df['LocationID'] = ''
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Alabama",'1',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Alaska",'2',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Arizona",'3',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Arkansas",'4',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "California",'5',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Colorado",'6',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Connecticut",'7',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Delaware",'8',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Florida",'9',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Georgia",'10',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Hawaii",'11',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Idaho",'12',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Illinois",'13',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Indiana",'14',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Iowa",'15',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Kansas",'16',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Kentucky",'17',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Louisiana",'18',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Maine",'19',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Maryland",'20',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Massachusetts",'21',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Michigan",'22',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Minnesota",'23',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Mississippi",'24',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Missouri",'25',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Montana",'26',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Nebraska",'27',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Nevada",'28',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "New Hampshire",'29',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "New Jersey",'30',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "New Mexico",'31',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "New York",'32',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "North Carolina",'33',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "North Dakota",'34',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Ohio",'35',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Oklahoma",'36',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Oregon",'37',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Pennsylvania",'38',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Rhode Island",'39',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "South Carolina",'40',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "South Dakota",'41',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Tennessee",'42',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Texas",'43',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Utah",'44',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Vermont",'45',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Virginia",'46',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Washington",'47',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "West Virginia",'48',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Wisconsin",'49',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Wyoming",'50',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "District of Columbia",'51',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Ontario",'52',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Quebec",'53',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Nova Scotia",'54',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "New Brunswick",'55',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Manitoba",'56',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "British Columbia",'57',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Prince Edward Island",'58',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Saskatchewan",'59',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Alberta",'60',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Newfoundland and Labrador",'61',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Northwest Territories",'62',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Yukon",'63',USfinal_df.LocationID)
USfinal_df['LocationID'] = np.where(USfinal_df.ProvinceOrState == "Nunavut",'64',USfinal_df.LocationID)

# %%
NoNYCfinal_df['LocationID'] = ''
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Alabama",'1',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Alaska",'2',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Arizona",'3',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Arkansas",'4',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "California",'5',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Colorado",'6',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Connecticut",'7',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Delaware",'8',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Florida",'9',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Georgia",'10',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Hawaii",'11',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Idaho",'12',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Illinois",'13',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Indiana",'14',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Iowa",'15',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Kansas",'16',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Kentucky",'17',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Louisiana",'18',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Maine",'19',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Maryland",'20',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Massachusetts",'21',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Michigan",'22',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Minnesota",'23',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Mississippi",'24',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Missouri",'25',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Montana",'26',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Nebraska",'27',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Nevada",'28',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "New Hampshire",'29',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "New Jersey",'30',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "New Mexico",'31',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "New York",'32',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "North Carolina",'33',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "North Dakota",'34',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Ohio",'35',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Oklahoma",'36',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Oregon",'37',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Pennsylvania",'38',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Rhode Island",'39',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "South Carolina",'40',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "South Dakota",'41',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Tennessee",'42',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Texas",'43',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Utah",'44',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Vermont",'45',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Virginia",'46',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Washington",'47',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "West Virginia",'48',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Wisconsin",'49',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Wyoming",'50',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "District of Columbia",'51',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Ontario",'52',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Quebec",'53',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Nova Scotia",'54',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "New Brunswick",'55',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Manitoba",'56',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "British Columbia",'57',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Prince Edward Island",'58',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Saskatchewan",'59',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Alberta",'60',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Newfoundland and Labrador",'61',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Northwest Territories",'62',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Yukon",'63',NoNYCfinal_df.LocationID)
NoNYCfinal_df['LocationID'] = np.where(NoNYCfinal_df.ProvinceOrState == "Nunavut",'64',NoNYCfinal_df.LocationID)

# %%
NoDCfinal_df['LocationID'] = ''
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Alabama",'1',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Alaska",'2',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Arizona",'3',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Arkansas",'4',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "California",'5',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Colorado",'6',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Connecticut",'7',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Delaware",'8',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Florida",'9',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Georgia",'10',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Hawaii",'11',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Idaho",'12',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Illinois",'13',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Indiana",'14',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Iowa",'15',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Kansas",'16',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Kentucky",'17',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Louisiana",'18',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Maine",'19',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Maryland",'20',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Massachusetts",'21',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Michigan",'22',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Minnesota",'23',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Mississippi",'24',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Missouri",'25',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Montana",'26',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Nebraska",'27',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Nevada",'28',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "New Hampshire",'29',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "New Jersey",'30',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "New Mexico",'31',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "New York",'32',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "North Carolina",'33',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "North Dakota",'34',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Ohio",'35',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Oklahoma",'36',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Oregon",'37',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Pennsylvania",'38',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Rhode Island",'39',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "South Carolina",'40',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "South Dakota",'41',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Tennessee",'42',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Texas",'43',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Utah",'44',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Vermont",'45',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Virginia",'46',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Washington",'47',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "West Virginia",'48',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Wisconsin",'49',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Wyoming",'50',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "District of Columbia",'51',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Ontario",'52',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Quebec",'53',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Nova Scotia",'54',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "New Brunswick",'55',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Manitoba",'56',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "British Columbia",'57',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Prince Edward Island",'58',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Saskatchewan",'59',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Alberta",'60',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Newfoundland and Labrador",'61',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Northwest Territories",'62',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Yukon",'63',NoDCfinal_df.LocationID)
NoDCfinal_df['LocationID'] = np.where(NoDCfinal_df.ProvinceOrState == "Nunavut",'64',NoDCfinal_df.LocationID)

# %%
NoNYCDCfinal_df['LocationID'] = ''
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Alabama",'1',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Alaska",'2',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Arizona",'3',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Arkansas",'4',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "California",'5',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Colorado",'6',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Connecticut",'7',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Delaware",'8',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Florida",'9',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Georgia",'10',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Hawaii",'11',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Idaho",'12',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Illinois",'13',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Indiana",'14',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Iowa",'15',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Kansas",'16',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Kentucky",'17',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Louisiana",'18',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Maine",'19',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Maryland",'20',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Massachusetts",'21',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Michigan",'22',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Minnesota",'23',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Mississippi",'24',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Missouri",'25',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Montana",'26',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Nebraska",'27',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Nevada",'28',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "New Hampshire",'29',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "New Jersey",'30',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "New Mexico",'31',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "New York",'32',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "North Carolina",'33',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "North Dakota",'34',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Ohio",'35',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Oklahoma",'36',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Oregon",'37',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Pennsylvania",'38',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Rhode Island",'39',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "South Carolina",'40',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "South Dakota",'41',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Tennessee",'42',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Texas",'43',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Utah",'44',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Vermont",'45',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Virginia",'46',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Washington",'47',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "West Virginia",'48',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Wisconsin",'49',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Wyoming",'50',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "District of Columbia",'51',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Ontario",'52',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Quebec",'53',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Nova Scotia",'54',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "New Brunswick",'55',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Manitoba",'56',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "British Columbia",'57',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Prince Edward Island",'58',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Saskatchewan",'59',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Alberta",'60',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Newfoundland and Labrador",'61',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Northwest Territories",'62',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Yukon",'63',NoNYCDCfinal_df.LocationID)
NoNYCDCfinal_df['LocationID'] = np.where(NoNYCDCfinal_df.ProvinceOrState == "Nunavut",'64',NoNYCDCfinal_df.LocationID)

# %% [markdown]
# ## Merge Datasets

# %%
NANoNYCfinal_df = NoNYCfinal_df

US_PopDen['MyID_USPopDen'] = US_PopDen['MyID_USPopDen'].astype(str)
Can_AgeHouse['MyID_CanAgeHouse'] = Can_AgeHouse['MyID_CanAgeHouse'].astype(str)
Can_PopDen['MyID_CanPopDen'] = Can_PopDen['MyID_CanPopDen'].astype(str)
Can_Obe['MyID_CanObe'] = Can_Obe['MyID_CanObe'].astype(str)
Can_GDP['MyID_CanGDP'] = Can_GDP['MyID_CanGDP'].astype(str)
US_Age['MyID_USAAge'] = US_Age['MyID_USAAge'].astype(str)
US_House['MyID_USAHouse'] = US_House['MyID_USAHouse'].astype(str)
US_GDP['MyID'] = US_GDP['MyID'].astype(str)
US_Obe['MyID'] = US_Obe['MyID'].astype(str)
USNoNYC_PopDen['MyID_USPopDen'] = USNoNYC_PopDen['MyID_USPopDen'].astype(str)
USNoNYC_Age['MyID_USAAge'] = USNoNYC_Age['MyID_USAAge'].astype(str)
USNoNYC_House['MyID_USAHouse'] = USNoNYC_House['MyID_USAHouse'].astype(str)
USNoNYC_GDP['MyID'] = USNoNYC_GDP['MyID'].astype(str)
Smoking_Drinking['MyID_SmkDrk'] = Smoking_Drinking['MyID_SmkDrk'].astype(str)

US_PopDen['MyID_USPopDen'] = US_PopDen['MyID_USPopDen'].str.split('.').str[0]
Can_AgeHouse['MyID_CanAgeHouse'] = Can_AgeHouse['MyID_CanAgeHouse'].str.split('.').str[0]
Can_PopDen['MyID_CanPopDen'] = Can_PopDen['MyID_CanPopDen'].str.split('.').str[0]
Can_Obe['MyID_CanObe'] = Can_Obe['MyID_CanObe'].str.split('.').str[0]
Can_GDP['MyID_CanGDP'] = Can_GDP['MyID_CanGDP'].str.split('.').str[0]
US_Age['MyID_USAAge'] = US_Age['MyID_USAAge'].str.split('.').str[0]
US_House['MyID_USAHouse'] = US_House['MyID_USAHouse'].str.split('.').str[0]
US_GDP['MyID'] = US_GDP['MyID'].str.split('.').str[0]
US_Obe['MyID'] = US_Obe['MyID'].str.split('.').str[0]
USNoNYC_PopDen['MyID_USPopDen'] = USNoNYC_PopDen['MyID_USPopDen'].str.split('.').str[0]
USNoNYC_Age['MyID_USAAge'] = USNoNYC_Age['MyID_USAAge'].str.split('.').str[0]
USNoNYC_House['MyID_USAHouse'] = USNoNYC_House['MyID_USAHouse'].str.split('.').str[0]
USNoNYC_GDP['MyID'] = USNoNYC_GDP['MyID'].str.split('.').str[0]
Smoking_Drinking['MyID_SmkDrk'] = Smoking_Drinking['MyID_SmkDrk'].str.split('.').str[0]

NAfinal_df = NAfinal_df.merge(US_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NAfinal_df = NAfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
NAfinal_df = NAfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
NAfinal_df = NAfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
NAfinal_df = NAfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
NAfinal_df = NAfinal_df.merge(US_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
NAfinal_df = NAfinal_df.merge(US_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
NAfinal_df = NAfinal_df.merge(US_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NAfinal_df = NAfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NAfinal_df = NAfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %%
CAfinal_df = CAfinal_df.merge(US_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
CAfinal_df = CAfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
CAfinal_df = CAfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
CAfinal_df = CAfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
CAfinal_df = CAfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
CAfinal_df = CAfinal_df.merge(US_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
CAfinal_df = CAfinal_df.merge(US_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
CAfinal_df = CAfinal_df.merge(US_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
CAfinal_df = CAfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
CAfinal_df = CAfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %%
USfinal_df = USfinal_df.merge(US_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
USfinal_df = USfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
USfinal_df = USfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
USfinal_df = USfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
USfinal_df = USfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
USfinal_df = USfinal_df.merge(US_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
USfinal_df = USfinal_df.merge(US_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
USfinal_df = USfinal_df.merge(US_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
USfinal_df = USfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
USfinal_df = USfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %%
NoNYCfinal_df = NoNYCfinal_df.merge(USNoNYC_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NoNYCfinal_df = NoNYCfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
NoNYCfinal_df = NoNYCfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
NoNYCfinal_df = NoNYCfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
NoNYCfinal_df = NoNYCfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
NoNYCfinal_df = NoNYCfinal_df.merge(USNoNYC_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
NoNYCfinal_df = NoNYCfinal_df.merge(USNoNYC_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
NoNYCfinal_df = NoNYCfinal_df.merge(USNoNYC_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NoNYCfinal_df = NoNYCfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NoNYCfinal_df = NoNYCfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %%
NANoNYCfinal_df = NANoNYCfinal_df.merge(USNoNYC_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NANoNYCfinal_df = NANoNYCfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
NANoNYCfinal_df = NANoNYCfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
NANoNYCfinal_df = NANoNYCfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
NANoNYCfinal_df = NANoNYCfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
NANoNYCfinal_df = NANoNYCfinal_df.merge(USNoNYC_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
NANoNYCfinal_df = NANoNYCfinal_df.merge(USNoNYC_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
NANoNYCfinal_df = NANoNYCfinal_df.merge(USNoNYC_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NANoNYCfinal_df = NANoNYCfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NANoNYCfinal_df = NANoNYCfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %%
NoDCfinal_df = NoDCfinal_df.merge(USNoNYC_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NoDCfinal_df = NoDCfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
NoDCfinal_df = NoDCfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
NoDCfinal_df = NoDCfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
NoDCfinal_df = NoDCfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
NoDCfinal_df = NoDCfinal_df.merge(USNoNYC_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
NoDCfinal_df = NoDCfinal_df.merge(USNoNYC_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
NoDCfinal_df = NoDCfinal_df.merge(USNoNYC_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NoDCfinal_df = NoDCfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NoDCfinal_df = NoDCfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %%
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(USNoNYC_PopDen,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(Can_AgeHouse, how='left', left_on='LocationID', right_on='MyID_CanAgeHouse')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(Can_PopDen, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanPopDen')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(Can_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanObe')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(Can_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID_CanGDP')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(USNoNYC_Age, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAAge')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(USNoNYC_House, how = 'left', left_on = 'LocationID', right_on = 'MyID_USAHouse')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(USNoNYC_GDP, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(US_Obe, how = 'left', left_on = 'LocationID', right_on = 'MyID')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(Smoking_Drinking, how = 'left', left_on = 'LocationID', right_on = 'MyID_SmkDrk')

# %% [markdown]
# ## Clean Up

# %%
def Country(row):
    if pd.isnull(row['Population Density per square mile']) == True:
        val = "Canada"
    else:
        val = "USA"
    return val

NAfinal_df = NAfinal_df.dropna(subset = ["LocationID"])
NAfinal_df = NAfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
NAfinal_df['Country'] = NAfinal_df.apply(Country, axis=1)
NAfinal_df['Land Area in Square Miles 2016'] = NAfinal_df['Land area in square kilometres, 2016']*0.621371
NAfinal_df['Population Density Per Square Miles 2016'] = NAfinal_df['Population, 2016']/NAfinal_df['Land Area in Square Miles 2016']
NAfinal_df['GDP Per Capita 2018 USD'] = NAfinal_df['GDP Per Capita (CAD, 2018)']*0.772
NAfinal_df['Total Obesity Rate'] = ""
NAfinal_df['Total Obesity Rate'] = np.where(NAfinal_df['Country'] == "USA", NAfinal_df['2018 Obesity Rate'], NAfinal_df['Total Obesity Rate'])
NAfinal_df['Total Obesity Rate'] = np.where(NAfinal_df['Country'] == "Canada", NAfinal_df['2017 Obesity Rate (%)'], NAfinal_df['Total Obesity Rate'])
NAfinal_df['Total Average Age'] = ""
NAfinal_df['Total Average Age'] = np.where(NAfinal_df['Country'] == "USA", NAfinal_df['Average Age_y'], NAfinal_df['Total Average Age'])
NAfinal_df['Total Average Age'] = np.where(NAfinal_df['Country'] == "Canada", NAfinal_df['Average Age_x'], NAfinal_df['Total Average Age'])
NAfinal_df['Total Average Household'] = ""
NAfinal_df['Total Average Household'] = np.where(NAfinal_df['Country'] == "USA", NAfinal_df['2018 Average Household Size'], NAfinal_df['Total Average Household'])
NAfinal_df['Total Average Household'] = np.where(NAfinal_df['Country'] == "Canada", NAfinal_df['Average Persons Per Household'], NAfinal_df['Total Average Household'])
NAfinal_df['Total Population Density'] = ""
NAfinal_df['Total Population Density'] = np.where(NAfinal_df['Country'] == "USA", NAfinal_df['Population Density per square mile'], NAfinal_df['Total Population Density'])
NAfinal_df['Total Population Density'] = np.where(NAfinal_df['Country'] == "Canada", NAfinal_df['Population Density Per Square Miles 2016'], NAfinal_df['Total Population Density'])
NAfinal_df['Total GDP Per Capita'] = ""
NAfinal_df['Total GDP Per Capita'] = np.where(NAfinal_df['Country'] == "USA", NAfinal_df['GDP Per Capita  (2019, USD)'], NAfinal_df['Total GDP Per Capita'])
NAfinal_df['Total GDP Per Capita'] = np.where(NAfinal_df['Country'] == "Canada", NAfinal_df['GDP Per Capita 2018 USD'], NAfinal_df['Total GDP Per Capita'])

# %%
CAfinal_df = CAfinal_df.dropna(subset = ["LocationID"])
CAfinal_df = CAfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
CAfinal_df['Country'] = CAfinal_df.apply(Country, axis=1)
CAfinal_df['Land Area in Square Miles 2016'] = CAfinal_df['Land area in square kilometres, 2016']*0.621371
CAfinal_df['Population Density Per Square Miles 2016'] = CAfinal_df['Population, 2016']/CAfinal_df['Land Area in Square Miles 2016']
CAfinal_df['GDP Per Capita 2018 USD'] = CAfinal_df['GDP Per Capita (CAD, 2018)']*0.772
CAfinal_df['Total Obesity Rate'] = ""
CAfinal_df['Total Obesity Rate'] = np.where(CAfinal_df['Country'] == "USA", CAfinal_df['2018 Obesity Rate'], CAfinal_df['Total Obesity Rate'])
CAfinal_df['Total Obesity Rate'] = np.where(CAfinal_df['Country'] == "Canada", CAfinal_df['2017 Obesity Rate (%)'], CAfinal_df['Total Obesity Rate'])
CAfinal_df['Total Average Age'] = ""
CAfinal_df['Total Average Age'] = np.where(CAfinal_df['Country'] == "USA", CAfinal_df['Average Age_y'], CAfinal_df['Total Average Age'])
CAfinal_df['Total Average Age'] = np.where(CAfinal_df['Country'] == "Canada", CAfinal_df['Average Age_x'], CAfinal_df['Total Average Age'])
CAfinal_df['Total Average Household'] = ""
CAfinal_df['Total Average Household'] = np.where(CAfinal_df['Country'] == "USA", CAfinal_df['2018 Average Household Size'], CAfinal_df['Total Average Household'])
CAfinal_df['Total Average Household'] = np.where(CAfinal_df['Country'] == "Canada", CAfinal_df['Average Persons Per Household'], CAfinal_df['Total Average Household'])
CAfinal_df['Total Population Density'] = ""
CAfinal_df['Total Population Density'] = np.where(CAfinal_df['Country'] == "USA", CAfinal_df['Population Density per square mile'], CAfinal_df['Total Population Density'])
CAfinal_df['Total Population Density'] = np.where(CAfinal_df['Country'] == "Canada", CAfinal_df['Population Density Per Square Miles 2016'], CAfinal_df['Total Population Density'])
CAfinal_df['Total GDP Per Capita'] = ""
CAfinal_df['Total GDP Per Capita'] = np.where(CAfinal_df['Country'] == "USA", CAfinal_df['GDP Per Capita  (2019, USD)'], CAfinal_df['Total GDP Per Capita'])
CAfinal_df['Total GDP Per Capita'] = np.where(CAfinal_df['Country'] == "Canada", CAfinal_df['GDP Per Capita 2018 USD'], CAfinal_df['Total GDP Per Capita'])

# %%
USfinal_df = USfinal_df.dropna(subset = ["LocationID"])
USfinal_df = USfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
USfinal_df['Country'] = USfinal_df.apply(Country, axis=1)
USfinal_df['Land Area in Square Miles 2016'] = USfinal_df['Land area in square kilometres, 2016']*0.621371
USfinal_df['Population Density Per Square Miles 2016'] = USfinal_df['Population, 2016']/USfinal_df['Land Area in Square Miles 2016']
USfinal_df['GDP Per Capita 2018 USD'] = USfinal_df['GDP Per Capita (CAD, 2018)']*0.772
USfinal_df['Total Obesity Rate'] = ""
USfinal_df['Total Obesity Rate'] = np.where(USfinal_df['Country'] == "USA", USfinal_df['2018 Obesity Rate'], USfinal_df['Total Obesity Rate'])
USfinal_df['Total Obesity Rate'] = np.where(USfinal_df['Country'] == "Canada", USfinal_df['2017 Obesity Rate (%)'], USfinal_df['Total Obesity Rate'])
USfinal_df['Total Average Age'] = ""
USfinal_df['Total Average Age'] = np.where(USfinal_df['Country'] == "USA", USfinal_df['Average Age_y'], USfinal_df['Total Average Age'])
USfinal_df['Total Average Age'] = np.where(USfinal_df['Country'] == "Canada", USfinal_df['Average Age_x'], USfinal_df['Total Average Age'])
USfinal_df['Total Average Household'] = ""
USfinal_df['Total Average Household'] = np.where(USfinal_df['Country'] == "USA", USfinal_df['2018 Average Household Size'], USfinal_df['Total Average Household'])
USfinal_df['Total Average Household'] = np.where(USfinal_df['Country'] == "Canada", USfinal_df['Average Persons Per Household'], USfinal_df['Total Average Household'])
USfinal_df['Total Population Density'] = ""
USfinal_df['Total Population Density'] = np.where(USfinal_df['Country'] == "USA", USfinal_df['Population Density per square mile'], USfinal_df['Total Population Density'])
USfinal_df['Total Population Density'] = np.where(USfinal_df['Country'] == "Canada", USfinal_df['Population Density Per Square Miles 2016'], USfinal_df['Total Population Density'])
USfinal_df['Total GDP Per Capita'] = ""
USfinal_df['Total GDP Per Capita'] = np.where(USfinal_df['Country'] == "USA", USfinal_df['GDP Per Capita  (2019, USD)'], USfinal_df['Total GDP Per Capita'])
USfinal_df['Total GDP Per Capita'] = np.where(USfinal_df['Country'] == "Canada", USfinal_df['GDP Per Capita 2018 USD'], USfinal_df['Total GDP Per Capita'])

# %%
NoNYCfinal_df = NoNYCfinal_df.dropna(subset = ["LocationID"])
NoNYCfinal_df = NoNYCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
NoNYCfinal_df['Country'] = NoNYCfinal_df.apply(Country, axis=1)
NoNYCfinal_df['Land Area in Square Miles 2016'] = NoNYCfinal_df['Land area in square kilometres, 2016']*0.621371
NoNYCfinal_df['Population Density Per Square Miles 2016'] = NoNYCfinal_df['Population, 2016']/NoNYCfinal_df['Land Area in Square Miles 2016']
NoNYCfinal_df['GDP Per Capita 2018 USD'] = NoNYCfinal_df['GDP Per Capita (CAD, 2018)']*0.772
NoNYCfinal_df['Total Obesity Rate'] = ""
NoNYCfinal_df['Total Obesity Rate'] = np.where(NoNYCfinal_df['Country'] == "USA", NoNYCfinal_df['2018 Obesity Rate'], NoNYCfinal_df['Total Obesity Rate'])
NoNYCfinal_df['Total Obesity Rate'] = np.where(NoNYCfinal_df['Country'] == "Canada", NoNYCfinal_df['2017 Obesity Rate (%)'], NoNYCfinal_df['Total Obesity Rate'])
NoNYCfinal_df['Total Average Age'] = ""
NoNYCfinal_df['Total Average Age'] = np.where(NoNYCfinal_df['Country'] == "USA", NoNYCfinal_df['Average Age_y'], NoNYCfinal_df['Total Average Age'])
NoNYCfinal_df['Total Average Age'] = np.where(NoNYCfinal_df['Country'] == "Canada", NoNYCfinal_df['Average Age_x'], NoNYCfinal_df['Total Average Age'])
NoNYCfinal_df['Total Average Household'] = ""
NoNYCfinal_df['Total Average Household'] = np.where(NoNYCfinal_df['Country'] == "USA", NoNYCfinal_df['2018 Average Household Size'], NoNYCfinal_df['Total Average Household'])
NoNYCfinal_df['Total Average Household'] = np.where(NoNYCfinal_df['Country'] == "Canada", NoNYCfinal_df['Average Persons Per Household'], NoNYCfinal_df['Total Average Household'])
NoNYCfinal_df['Total Population Density'] = ""
NoNYCfinal_df['Total Population Density'] = np.where(NoNYCfinal_df['Country'] == "USA", NoNYCfinal_df['Population Density per square mile'], NoNYCfinal_df['Total Population Density'])
NoNYCfinal_df['Total Population Density'] = np.where(NoNYCfinal_df['Country'] == "Canada", NoNYCfinal_df['Population Density Per Square Miles 2016'], NoNYCfinal_df['Total Population Density'])
NoNYCfinal_df['Total GDP Per Capita'] = ""
NoNYCfinal_df['Total GDP Per Capita'] = np.where(NoNYCfinal_df['Country'] == "USA", NoNYCfinal_df['GDP Per Capita  (2019, USD)'], NoNYCfinal_df['Total GDP Per Capita'])
NoNYCfinal_df['Total GDP Per Capita'] = np.where(NoNYCfinal_df['Country'] == "Canada", NoNYCfinal_df['GDP Per Capita 2018 USD'], NoNYCfinal_df['Total GDP Per Capita'])

# %%
NANoNYCfinal_df = NANoNYCfinal_df.dropna(subset = ["LocationID"])
NANoNYCfinal_df = NANoNYCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
NANoNYCfinal_df['Country'] = NANoNYCfinal_df.apply(Country, axis=1)
NANoNYCfinal_df['Land Area in Square Miles 2016'] = NANoNYCfinal_df['Land area in square kilometres, 2016']*0.621371
NANoNYCfinal_df['Population Density Per Square Miles 2016'] = NANoNYCfinal_df['Population, 2016']/NANoNYCfinal_df['Land Area in Square Miles 2016']
NANoNYCfinal_df['GDP Per Capita 2018 USD'] = NANoNYCfinal_df['GDP Per Capita (CAD, 2018)']*0.772
NANoNYCfinal_df['Total Obesity Rate'] = ""
NANoNYCfinal_df['Total Obesity Rate'] = np.where(NANoNYCfinal_df['Country'] == "USA", NANoNYCfinal_df['2018 Obesity Rate'], NANoNYCfinal_df['Total Obesity Rate'])
NANoNYCfinal_df['Total Obesity Rate'] = np.where(NANoNYCfinal_df['Country'] == "Canada", NANoNYCfinal_df['2017 Obesity Rate (%)'], NANoNYCfinal_df['Total Obesity Rate'])
NANoNYCfinal_df['Total Average Age'] = ""
NANoNYCfinal_df['Total Average Age'] = np.where(NANoNYCfinal_df['Country'] == "USA", NANoNYCfinal_df['Average Age_y'], NANoNYCfinal_df['Total Average Age'])
NANoNYCfinal_df['Total Average Age'] = np.where(NANoNYCfinal_df['Country'] == "Canada", NANoNYCfinal_df['Average Age_x'], NANoNYCfinal_df['Total Average Age'])
NANoNYCfinal_df['Total Average Household'] = ""
NANoNYCfinal_df['Total Average Household'] = np.where(NANoNYCfinal_df['Country'] == "USA", NANoNYCfinal_df['2018 Average Household Size'], NANoNYCfinal_df['Total Average Household'])
NANoNYCfinal_df['Total Average Household'] = np.where(NANoNYCfinal_df['Country'] == "Canada", NANoNYCfinal_df['Average Persons Per Household'], NANoNYCfinal_df['Total Average Household'])
NANoNYCfinal_df['Total Population Density'] = ""
NANoNYCfinal_df['Total Population Density'] = np.where(NANoNYCfinal_df['Country'] == "USA", NANoNYCfinal_df['Population Density per square mile'], NANoNYCfinal_df['Total Population Density'])
NANoNYCfinal_df['Total Population Density'] = np.where(NANoNYCfinal_df['Country'] == "Canada", NANoNYCfinal_df['Population Density Per Square Miles 2016'], NANoNYCfinal_df['Total Population Density'])
NANoNYCfinal_df['Total GDP Per Capita'] = ""
NANoNYCfinal_df['Total GDP Per Capita'] = np.where(NANoNYCfinal_df['Country'] == "USA", NANoNYCfinal_df['GDP Per Capita  (2019, USD)'], NANoNYCfinal_df['Total GDP Per Capita'])
NANoNYCfinal_df['Total GDP Per Capita'] = np.where(NANoNYCfinal_df['Country'] == "Canada", NANoNYCfinal_df['GDP Per Capita 2018 USD'], NANoNYCfinal_df['Total GDP Per Capita'])

# %%
NoDCfinal_df = NoDCfinal_df.dropna(subset = ["LocationID"])
NoDCfinal_df = NoDCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
NoDCfinal_df['Country'] = NoDCfinal_df.apply(Country, axis=1)
NoDCfinal_df['Land Area in Square Miles 2016'] = NoDCfinal_df['Land area in square kilometres, 2016']*0.621371
NoDCfinal_df['Population Density Per Square Miles 2016'] = NoDCfinal_df['Population, 2016']/NoDCfinal_df['Land Area in Square Miles 2016']
NoDCfinal_df['GDP Per Capita 2018 USD'] = NoDCfinal_df['GDP Per Capita (CAD, 2018)']*0.772
NoDCfinal_df['Total Obesity Rate'] = ""
NoDCfinal_df['Total Obesity Rate'] = np.where(NoDCfinal_df['Country'] == "USA", NoDCfinal_df['2018 Obesity Rate'], NoDCfinal_df['Total Obesity Rate'])
NoDCfinal_df['Total Obesity Rate'] = np.where(NoDCfinal_df['Country'] == "Canada", NoDCfinal_df['2017 Obesity Rate (%)'], NoDCfinal_df['Total Obesity Rate'])
NoDCfinal_df['Total Average Age'] = ""
NoDCfinal_df['Total Average Age'] = np.where(NoDCfinal_df['Country'] == "USA", NoDCfinal_df['Average Age_y'], NoDCfinal_df['Total Average Age'])
NoDCfinal_df['Total Average Age'] = np.where(NoDCfinal_df['Country'] == "Canada", NoDCfinal_df['Average Age_x'], NoDCfinal_df['Total Average Age'])
NoDCfinal_df['Total Average Household'] = ""
NoDCfinal_df['Total Average Household'] = np.where(NoDCfinal_df['Country'] == "USA", NoDCfinal_df['2018 Average Household Size'], NoDCfinal_df['Total Average Household'])
NoDCfinal_df['Total Average Household'] = np.where(NoDCfinal_df['Country'] == "Canada", NoDCfinal_df['Average Persons Per Household'], NoDCfinal_df['Total Average Household'])
NoDCfinal_df['Total Population Density'] = ""
NoDCfinal_df['Total Population Density'] = np.where(NoDCfinal_df['Country'] == "USA", NoDCfinal_df['Population Density per square mile'], NoDCfinal_df['Total Population Density'])
NoDCfinal_df['Total Population Density'] = np.where(NoDCfinal_df['Country'] == "Canada", NoDCfinal_df['Population Density Per Square Miles 2016'], NoDCfinal_df['Total Population Density'])
NoDCfinal_df['Total GDP Per Capita'] = ""
NoDCfinal_df['Total GDP Per Capita'] = np.where(NoDCfinal_df['Country'] == "USA", NoDCfinal_df['GDP Per Capita  (2019, USD)'], NoDCfinal_df['Total GDP Per Capita'])
NoDCfinal_df['Total GDP Per Capita'] = np.where(NoDCfinal_df['Country'] == "Canada", NoDCfinal_df['GDP Per Capita 2018 USD'], NoDCfinal_df['Total GDP Per Capita'])

# %%
NoNYCDCfinal_df = NoNYCDCfinal_df.dropna(subset = ["LocationID"])
NoNYCDCfinal_df = NoNYCDCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1).drop('Province/Territory_CanAgeHouse', axis = 1).drop('MyID_CanAgeHouse', axis = 1).drop('Geographic code', axis = 1).drop('Province/Territory_CanPopDen', axis = 1).drop('MyID_CanPopDen', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2016', axis = 1).drop('2011 adjusted population flag', axis = 1).drop('Incompletely enumerated Indian reserves and Indian settlements, 2011', axis = 1).drop('Location_CanObe', axis = 1).drop('MyID_CanObe', axis = 1).drop('Location_CanGDP', axis = 1).drop('MyID_CanGDP', axis = 1).drop('State_USAAge', axis = 1).drop('MyID_USAAge', axis = 1).drop('State_USAHouse', axis = 1).drop('MyID_USAHouse', axis = 1).drop('Location', axis = 1).drop('MyID_x', axis = 1).drop('State', axis = 1).drop('MyID_y', axis = 1)
NoNYCDCfinal_df['Country'] = NoNYCDCfinal_df.apply(Country, axis=1)
NoNYCDCfinal_df['Land Area in Square Miles 2016'] = NoNYCDCfinal_df['Land area in square kilometres, 2016']*0.621371
NoNYCDCfinal_df['Population Density Per Square Miles 2016'] = NoNYCDCfinal_df['Population, 2016']/NoNYCDCfinal_df['Land Area in Square Miles 2016']
NoNYCDCfinal_df['GDP Per Capita 2018 USD'] = NoNYCDCfinal_df['GDP Per Capita (CAD, 2018)']*0.772
NoNYCDCfinal_df['Total Obesity Rate'] = ""
NoNYCDCfinal_df['Total Obesity Rate'] = np.where(NoNYCDCfinal_df['Country'] == "USA", NoNYCDCfinal_df['2018 Obesity Rate'], NoNYCDCfinal_df['Total Obesity Rate'])
NoNYCDCfinal_df['Total Obesity Rate'] = np.where(NoNYCDCfinal_df['Country'] == "Canada", NoNYCDCfinal_df['2017 Obesity Rate (%)'], NoNYCDCfinal_df['Total Obesity Rate'])
NoNYCDCfinal_df['Total Average Age'] = ""
NoNYCDCfinal_df['Total Average Age'] = np.where(NoNYCDCfinal_df['Country'] == "USA", NoNYCDCfinal_df['Average Age_y'], NoNYCDCfinal_df['Total Average Age'])
NoNYCDCfinal_df['Total Average Age'] = np.where(NoNYCDCfinal_df['Country'] == "Canada", NoNYCDCfinal_df['Average Age_x'], NoNYCDCfinal_df['Total Average Age'])
NoNYCDCfinal_df['Total Average Household'] = ""
NoNYCDCfinal_df['Total Average Household'] = np.where(NoNYCDCfinal_df['Country'] == "USA", NoNYCDCfinal_df['2018 Average Household Size'], NoNYCDCfinal_df['Total Average Household'])
NoNYCDCfinal_df['Total Average Household'] = np.where(NoNYCDCfinal_df['Country'] == "Canada", NoNYCDCfinal_df['Average Persons Per Household'], NoNYCDCfinal_df['Total Average Household'])
NoNYCDCfinal_df['Total Population Density'] = ""
NoNYCDCfinal_df['Total Population Density'] = np.where(NoNYCDCfinal_df['Country'] == "USA", NoNYCDCfinal_df['Population Density per square mile'], NoNYCDCfinal_df['Total Population Density'])
NoNYCDCfinal_df['Total Population Density'] = np.where(NoNYCDCfinal_df['Country'] == "Canada", NoNYCDCfinal_df['Population Density Per Square Miles 2016'], NoNYCDCfinal_df['Total Population Density'])
NoNYCDCfinal_df['Total GDP Per Capita'] = ""
NoNYCDCfinal_df['Total GDP Per Capita'] = np.where(NoNYCDCfinal_df['Country'] == "USA", NoNYCDCfinal_df['GDP Per Capita  (2019, USD)'], NoNYCDCfinal_df['Total GDP Per Capita'])
NoNYCDCfinal_df['Total GDP Per Capita'] = np.where(NoNYCDCfinal_df['Country'] == "Canada", NoNYCDCfinal_df['GDP Per Capita 2018 USD'], NoNYCDCfinal_df['Total GDP Per Capita'])

# %% [markdown]
# ## Drop Columns

# %%
NAfinal_df = NAfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

CAfinal_df = CAfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

USfinal_df = USfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

NoNYCfinal_df = NoNYCfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

NANoNYCfinal_df = NANoNYCfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

NoDCfinal_df = NoDCfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

NoNYCDCfinal_df = NoNYCDCfinal_df.drop('MyID_SmkDrk', axis = 1).drop('Population Density per square mile', axis = 1).drop('Population Density per square km', axis = 1).drop('Population', axis = 1).drop('Land area mi2', axis = 1).drop('Land area km2', axis = 1).drop('Population, 2016', axis = 1).drop('Population, 2011', axis = 1).drop('Population, % change', axis = 1).drop('Average Age_x', axis = 1).drop('Average Persons Per Household', axis = 1).drop('Total private dwellings, 2016', axis = 1).drop('Private dwellings occupied by usual residents, 2016', axis = 1).drop('Land area in square kilometres, 2016', axis = 1).drop('Population density per square kilometre, 2016', axis = 1).drop('2017 Obesity Rate (%)', axis = 1).drop('2012 Obesity Rate (%)', axis = 1).drop('Percent Change', axis = 1).drop('GDP (CAD, millions)', axis = 1).drop('GDP Per Capita (CAD, 2018)', axis = 1).drop('Average Age_y', axis = 1).drop('2018 Average Household Size', axis = 1).drop('GDP Per Capita  (2019, USD)', axis = 1).drop('2018 Obesity Rate', axis = 1).drop('95% Confidence Interval', axis = 1).drop('Land Area in Square Miles 2016', axis = 1).drop('Population Density Per Square Miles 2016', axis = 1).drop('GDP Per Capita 2018 USD', axis = 1)

# %% [markdown]
# ## Drop Rows With No Location ID

# %%
NAfinal_df = NAfinal_df.loc[~(NAfinal_df['LocationID'] == ""),:] #done
CAfinal_df = CAfinal_df.loc[~(CAfinal_df['LocationID'] == ""),:] #done
USfinal_df = USfinal_df.loc[~(USfinal_df['LocationID'] == ""),:] #done
NoNYCfinal_df = NoNYCfinal_df.loc[~(NoNYCfinal_df['LocationID'] == ""),:] #done
NANoNYCfinal_df = NANoNYCfinal_df.loc[~(NANoNYCfinal_df['LocationID'] == ""),:] #done
NoDCfinal_df = NoDCfinal_df.loc[~(NoDCfinal_df['LocationID'] == ""),:] 
NoNYCDCfinal_df = NoNYCDCfinal_df.loc[~(NoNYCDCfinal_df['LocationID'] == ""),:] #done

# %% [markdown]
# ## Drop Extra Columns

# %%
NAfinal_df = NAfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)
CAfinal_df = CAfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)
USfinal_df = USfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)
NoNYCfinal_df = NoNYCfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)
NANoNYCfinal_df = NANoNYCfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)
NoDCfinal_df = NoDCfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)
NoNYCDCfinal_df = NoNYCDCfinal_df.drop('Case-Fatality_Ratio', axis = 1).drop('Incidence_Rate', axis = 1).drop('ProvinceOrState_y', axis = 1)

NAfinal_df['ProvinceOrState'] = NAfinal_df['ProvinceOrState_x']
NAfinal_df = NAfinal_df.drop('ProvinceOrState_x', axis = 1)

CAfinal_df['ProvinceOrState'] = CAfinal_df['ProvinceOrState_x']
CAfinal_df = CAfinal_df.drop('ProvinceOrState_x', axis = 1)

USfinal_df['ProvinceOrState'] = USfinal_df['ProvinceOrState_x']
USfinal_df = USfinal_df.drop('ProvinceOrState_x', axis = 1)

NoNYCfinal_df['ProvinceOrState'] = NoNYCfinal_df['ProvinceOrState_x']
NoNYCfinal_df = NoNYCfinal_df.drop('ProvinceOrState_x', axis = 1)

NANoNYCfinal_df['ProvinceOrState'] = NANoNYCfinal_df['ProvinceOrState_x']
NANoNYCfinal_df = NANoNYCfinal_df.drop('ProvinceOrState_x', axis = 1)

NoDCfinal_df['ProvinceOrState'] = NoDCfinal_df['ProvinceOrState_x']
NoDCfinal_df = NoDCfinal_df.drop('ProvinceOrState_x', axis = 1)

NoNYCDCfinal_df['ProvinceOrState'] = NoNYCDCfinal_df['ProvinceOrState_x']
NoNYCDCfinal_df = NoNYCDCfinal_df.drop('ProvinceOrState_x', axis = 1)

# %% [markdown]
# ## Add Population Files

# %%
Canada_Pop = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\_Canada Population.csv")
NA_NoNYC_Pop = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\_NA (No NYC) Population.csv")
NA_Pop = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\_NA Population.csv")
US_NoNYC_Pop = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\_USA (No NYC) Population.csv")
US_Pop = pd.read_csv("C:\\Users\\Acer\\Desktop\\unBDC\\Clean\\CSV\\_USA Population.csv")

Canada_Pop['MyID_CanPopDen'] = Canada_Pop['MyID_CanPopDen'].astype(str)
Canada_Pop['MyID_CanPopDen'] = Canada_Pop['MyID_CanPopDen'].str.split('.').str[0]

NA_NoNYC_Pop['MyID_USPopDen'] = NA_NoNYC_Pop['MyID_USPopDen'].astype(str)
NA_NoNYC_Pop['MyID_USPopDen'] = NA_NoNYC_Pop['MyID_USPopDen'].str.split('.').str[0]

NA_Pop['MyID_USPopDen'] = NA_Pop['MyID_USPopDen'].astype(str)
NA_Pop['MyID_USPopDen'] = NA_Pop['MyID_USPopDen'].str.split('.').str[0]

US_NoNYC_Pop['MyID_USPopDen'] = US_NoNYC_Pop['MyID_USPopDen'].astype(str)
US_NoNYC_Pop['MyID_USPopDen'] = US_NoNYC_Pop['MyID_USPopDen'].str.split('.').str[0]

US_Pop['MyID_USPop'] = US_Pop['MyID_USPop'].astype(str)
US_Pop['MyID_USPop'] = US_Pop['MyID_USPop'].str.split('.').str[0]

# %% [markdown]
# ## Create Canda & USA Datasets

# %%
CAfinal_df = CAfinal_df.loc[(CAfinal_df['Country'] == "Canada"),:]
USfinal_df = USfinal_df.loc[(USfinal_df['Country'] == "USA"),:]
NoNYCfinal_df = NoNYCfinal_df.loc[(NoNYCfinal_df['Country'] == "USA"),:]

# %% [markdown]
# ## Merge Populations And Calculate Percentages

# %%
NAfinal_df = NAfinal_df.merge(NA_Pop,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NANoNYCfinal_df = NANoNYCfinal_df.merge(NA_NoNYC_Pop,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NoNYCDCfinal_df = NoNYCDCfinal_df.merge(NA_NoNYC_Pop,how='left', left_on='LocationID', right_on='MyID_USPopDen')
NoDCfinal_df = NoDCfinal_df.merge(NA_Pop,how='left', left_on='LocationID', right_on='MyID_USPopDen')
CAfinal_df = CAfinal_df.merge(Canada_Pop,how='left', left_on='LocationID', right_on='MyID_CanPopDen')
USfinal_df = USfinal_df.merge(US_Pop,how='left', left_on='LocationID', right_on='MyID_USPop')
NoNYCfinal_df = NoNYCfinal_df.merge(US_NoNYC_Pop,how='left', left_on='LocationID', right_on='MyID_USPopDen')

# %%
NAfinal_df['Population'] = NAfinal_df['Population'].str.replace(',', '')
NAfinal_df['Confirmed'] = NAfinal_df['Confirmed'].astype(float)
NAfinal_df['Population'] = NAfinal_df['Population'].astype(float)
NAfinal_df['Deaths'] = NAfinal_df['Deaths'].astype(float)
NAfinal_df['Percent Infected'] = NAfinal_df['Confirmed']/NAfinal_df['Population']
NAfinal_df['Pop Mortality Rate'] = NAfinal_df['Deaths']/NAfinal_df['Population']
NAfinal_df['Infected Mortality Rate'] = NAfinal_df['Deaths']/NAfinal_df['Confirmed']
NAfinal_df = NAfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1)

# %%
NANoNYCfinal_df['Population'] = NANoNYCfinal_df['Population'].str.replace(',', '')
NANoNYCfinal_df['Confirmed'] = NANoNYCfinal_df['Confirmed'].astype(float)
NANoNYCfinal_df['Population'] = NANoNYCfinal_df['Population'].astype(float)
NANoNYCfinal_df['Deaths'] = NANoNYCfinal_df['Deaths'].astype(float)
NANoNYCfinal_df['Percent Infected'] = NANoNYCfinal_df['Confirmed']/NANoNYCfinal_df['Population']
NANoNYCfinal_df['Pop Mortality Rate'] = NANoNYCfinal_df['Deaths']/NANoNYCfinal_df['Population']
NANoNYCfinal_df['Infected Mortality Rate'] = NANoNYCfinal_df['Deaths']/NANoNYCfinal_df['Confirmed']
NANoNYCfinal_df = NANoNYCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1)

# %%
NoNYCDCfinal_df['Population'] = NoNYCDCfinal_df['Population'].str.replace(',', '')
NoNYCDCfinal_df['Confirmed'] = NoNYCDCfinal_df['Confirmed'].astype(float)
NoNYCDCfinal_df['Population'] = NoNYCDCfinal_df['Population'].astype(float)
NoNYCDCfinal_df['Deaths'] = NoNYCDCfinal_df['Deaths'].astype(float)
NoNYCDCfinal_df['Percent Infected'] = NoNYCDCfinal_df['Confirmed']/NoNYCDCfinal_df['Population']
NoNYCDCfinal_df['Pop Mortality Rate'] = NoNYCDCfinal_df['Deaths']/NoNYCDCfinal_df['Population']
NoNYCDCfinal_df['Infected Mortality Rate'] = NoNYCDCfinal_df['Deaths']/NoNYCDCfinal_df['Confirmed']
NoNYCDCfinal_df = NoNYCDCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1)

# %%
NoDCfinal_df['Population'] = NoDCfinal_df['Population'].str.replace(',', '')
NoDCfinal_df['Confirmed'] = NoDCfinal_df['Confirmed'].astype(float)
NoDCfinal_df['Population'] = NoDCfinal_df['Population'].astype(float)
NoDCfinal_df['Deaths'] = NoDCfinal_df['Deaths'].astype(float)
NoDCfinal_df['Percent Infected'] = NoDCfinal_df['Confirmed']/NoDCfinal_df['Population']
NoDCfinal_df['Pop Mortality Rate'] = NoDCfinal_df['Deaths']/NoDCfinal_df['Population']
NoDCfinal_df['Infected Mortality Rate'] = NoDCfinal_df['Deaths']/NoDCfinal_df['Confirmed']
NoDCfinal_df = NoDCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1)

# %%
CAfinal_df['Confirmed'] = CAfinal_df['Confirmed'].astype(float)
CAfinal_df['Population, 2016'] = CAfinal_df['Population, 2016'].astype(float)
CAfinal_df['Deaths'] = CAfinal_df['Deaths'].astype(float)
CAfinal_df['Percent Infected'] = CAfinal_df['Confirmed']/CAfinal_df['Population, 2016']
CAfinal_df['Pop Mortality Rate'] = CAfinal_df['Deaths']/CAfinal_df['Population, 2016']
CAfinal_df['Infected Mortality Rate'] = CAfinal_df['Deaths']/CAfinal_df['Confirmed']
CAfinal_df = CAfinal_df.drop("Province/Territory_CanPopDen", axis = 1).drop('MyID_CanPopDen', axis = 1)

# %%
USfinal_df['Population'] = USfinal_df['Population'].str.replace(',', '')
USfinal_df['Confirmed'] = USfinal_df['Confirmed'].astype(float)
USfinal_df['Population'] = USfinal_df['Population'].astype(float)
USfinal_df['Deaths'] = USfinal_df['Deaths'].astype(float)
USfinal_df['Percent Infected'] = USfinal_df['Confirmed']/USfinal_df['Population']
USfinal_df['Pop Mortality Rate'] = USfinal_df['Deaths']/USfinal_df['Population']
USfinal_df['Infected Mortality Rate'] = USfinal_df['Deaths']/USfinal_df['Confirmed']
USfinal_df = USfinal_df.drop('State_Province', axis = 1).drop('MyID_USPop', axis = 1)

# %%
NoNYCfinal_df['Population_NoNYC'] = NoNYCfinal_df['Population_NoNYC'].str.replace(',', '')
NoNYCfinal_df['Confirmed'] = NoNYCfinal_df['Confirmed'].astype(float)
NoNYCfinal_df['Population_NoNYC'] = NoNYCfinal_df['Population_NoNYC'].astype(float)
NoNYCfinal_df['Deaths'] = NoNYCfinal_df['Deaths'].astype(float)
NoNYCfinal_df['Percent Infected'] = NoNYCfinal_df['Confirmed']/NoNYCfinal_df['Population_NoNYC']
NoNYCfinal_df['Pop Mortality Rate'] = NoNYCfinal_df['Deaths']/NoNYCfinal_df['Population_NoNYC']
NoNYCfinal_df['Infected Mortality Rate'] = NoNYCfinal_df['Deaths']/NoNYCfinal_df['Confirmed']
NoNYCfinal_df = NoNYCfinal_df.drop('StateUS_PopDen', axis = 1).drop('MyID_USPopDen', axis = 1)

# %% [markdown]
# ## Save North America & Full No NYC As CSV

# %%
NAfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\NACovid.csv", index = False, sep = ',', encoding = 'utf-8')
NANoNYCfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\NANoNYCCovid.csv", index = False, sep = ',', encoding = 'utf-8')
NoNYCDCfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\NANoNYCCDCCovid.csv", index = False, sep = ',', encoding = 'utf-8')
NoDCfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\NANoDCCovid.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
NoNYCDCfinal_df = NoNYCDCfinal_df.loc[(NoNYCDCfinal_df['Country'] == "USA"),:]
NoDCfinal_df = NoDCfinal_df.loc[(NoDCfinal_df['Country'] == "USA"),:]

# %% [markdown]
# ## Save Country Dataframes As CSV's

# %%
CAfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\CACovid.csv", index = False, sep = ',', encoding = 'utf-8')
USfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\USCovid.csv", index = False, sep = ',', encoding = 'utf-8')
NoNYCfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\USNoNYCCovid.csv", index = False, sep = ',', encoding = 'utf-8')
NoNYCDCfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\USNoNYCDCCovid.csv", index = False, sep = ',', encoding = 'utf-8')
NoDCfinal_df.to_csv(r"C:\\Users\\Acer\\Desktop\\unBDC\\USNoDCCovid.csv", index = False, sep = ',', encoding = 'utf-8')
